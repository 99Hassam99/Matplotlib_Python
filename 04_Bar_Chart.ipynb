# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
company = ['GOOGLE','MICROSOFT','AMAZON','FACEBOOK']
revenue = [55,97,70,89]
profit = [10,40,15,30]

# %%
plt.bar(company,revenue)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# It work like that also. But in real it needs the owner of the bar(that is the first name) to be a string so for that

# %%
xpos=np.arange(len(company))
xpos
# Out:
# array([0, 1, 2, 3])

# %%
plt.bar(xpos,revenue)
# Out:
# <BarContainer object of 4 artists>

# %%
# now we have these numbers so to exchange these numbers with Company name we havee to define another function

# %%
plt.xticks(ypos,company)
plt.ylabel('revenue(bln)')
plt.title('US Tech stocks')
plt.bar(xpos,revenue,label="Revenue")

plt.legend()

# %%
# as we define profit so for profit to be in the chart we need to define it

# %%
plt.xticks(ypos,company)
plt.ylabel('revenue(bln)')
plt.title('US Tech stocks')
plt.bar(xpos-0.2,revenue, width= 0.35, label="Revenue")
plt.bar(xpos+0.2,profit, width= 0.35, label="Profit")
plt.legend()

# %%
# for horizontal fashion

# %%
plt.yticks(ypos,company)
plt.title('US Tech stocks')

plt.barh(xpos-0.2,revenue, height= 0.3, label="Revenue")
plt.barh(xpos+0.2,profit, height= 0.3, label="Profit")
plt.legend(loc='best', shadow=True,fontsize='small')
